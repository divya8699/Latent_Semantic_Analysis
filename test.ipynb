# %%
install.packages('pdftools')
install.packages('tm')
install.packages('lsa')
install.packages('LSAfun')
# Out:
# Installing package into 'C:/Users/divya/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
#
# also installing the dependency 'qpdf'
# package 'qpdf' successfully unpacked and MD5 sums checked
# package 'pdftools' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\divya\AppData\Local\Temp\RtmpukwNZh\downloaded_packages
# Installing package into 'C:/Users/divya/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
#
# also installing the dependencies 'NLP', 'slam', 'BH'
# package 'NLP' successfully unpacked and MD5 sums checked
# package 'slam' successfully unpacked and MD5 sums checked
# package 'BH' successfully unpacked and MD5 sums checked
# package 'tm' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\divya\AppData\Local\Temp\RtmpukwNZh\downloaded_packages
# Installing package into 'C:/Users/divya/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
#
# also installing the dependency 'SnowballC'
# package 'SnowballC' successfully unpacked and MD5 sums checked
# package 'lsa' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\divya\AppData\Local\Temp\RtmpukwNZh\downloaded_packages
# Installing package into 'C:/Users/divya/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
# package 'LSAfun' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\divya\AppData\Local\Temp\RtmpukwNZh\downloaded_packages

# %%
require(pdftools)
require(tm)
require(lsa)
require(LSAfun)
# Out:
# Loading required package: pdftools
# Warning message:
# "package 'pdftools' was built under R version 4.4.2"
# Using poppler version 23.08.0
#
# Loading required package: tm
#
# Warning message:
# "package 'tm' was built under R version 4.4.2"
# Loading required package: NLP
#
# Warning message:
# "package 'NLP' was built under R version 4.4.2"
# Loading required package: lsa
#
# Warning message:
# "package 'lsa' was built under R version 4.4.2"
# Loading required package: SnowballC
#
# Loading required package: LSAfun
#
# Warning message:
# "package 'LSAfun' was built under R version 4.4.2"
# Loading required package: rgl
#
# Warning message:
# "package 'rgl' was built under R version 4.4.1"

# %%
files <- list.files(pattern = ".pdf$")

# %%
docs <- sapply(files, pdf_text, USE.NAMES = TRUE)
# Out:
# PDF error: Couldn't find trailer dictionary
#
# PDF error: Couldn't find trailer dictionary
#
# PDF error: Couldn't read xref table
# Error in eval(expr, envir, enclos): PDF parsing failure.
# Traceback:
#
# 1. sapply(files, pdf_text, USE.NAMES = TRUE)
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. poppler_pdf_text(loadfile(pdf), opw, upw)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
